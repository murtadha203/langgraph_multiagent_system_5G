# %% [markdown]
# Simplified 5G/6G mobility + MEC/offloading environment
# for a multi-agent decision system.
#
# The goal is not to be 3GPP-accurate, but to provide a consistent,
# controllable world where different decision policies can be tested.
#
# Main entry point: NetworkSimulation
#
# - reset(service_type, ...) -> initial context
# - get_context() -> current observable state
# - step(decision) -> (next_context, info)
# - run_episode(num_steps, controller_fn) -> trace list

# %%
from __future__ import annotations

import math
import random
from dataclasses import dataclass, field
from typing import Dict, List, Optional, Tuple, Any

import numpy as np

# %% [markdown]
# # Utility functions

# %%
def dbm_to_watts(dbm: float) -> float: 
    return 10 ** ((dbm - 30) / 10.0)

# %%
def watts_to_dbm(watts: float) -> float:
    if watts <= 0:
        return -200.0
    return 10 * math.log10(watts) + 30

# %%
def path_loss_db(distance_m: float,
                 pl0_db: float = 30.0,
                 path_loss_exp: float = 3.5) -> float:
    """
    PL(d) = PL0 + 10 * n * log10(d / d0)
    """
    d = max(distance_m, 1.0)
    return pl0_db + 10 * path_loss_exp * math.log10(d)

# %%
def shannon_capacity_hz(bandwidth_hz: float, sinr_linear: float) -> float:
    """C = B * log2(1 + SINR)"""
    return bandwidth_hz * math.log2(1.0 + sinr_linear)

# %% [markdown]
# # Data models

# %%
@dataclass
class BaseStation:
    id: int
    x: float
    y: float
    tx_power_dbm: float = 46.0  # ~40W
    noise_dbm: float = -100.0   # thermal noise + receiver noise
    bandwidth_mhz: float = 20.0

    def distance_to(self, x: float, y: float) -> float:
        return math.hypot(self.x - x, self.y - y)

# %%
@dataclass
class UserEquipment:
    x: float
    y: float
    speed_mps: float
    direction_rad: float
    local_cpu_ghz: float = 2.0
    battery_joules: float = 1000.0

    def step(self, dt_s: float, area_size: Tuple[float, float]) -> None:
        """Move UE with simple constant velocity model and reflecting borders."""
        dx = self.speed_mps * math.cos(self.direction_rad) * dt_s
        dy = self.speed_mps * math.sin(self.direction_rad) * dt_s

        new_x = self.x + dx
        new_y = self.y + dy
        max_x, max_y = area_size

        # Reflect from borders
        if new_x < 0 or new_x > max_x:
            self.direction_rad = math.pi - self.direction_rad
            new_x = max(0, min(max_x, new_x))
        if new_y < 0 or new_y > max_y:
            self.direction_rad = -self.direction_rad
            new_y = max(0, min(max_y, new_y))

        self.x = new_x
        self.y = new_y

# %%
@dataclass
class Task:
    id: int
    arrival_time_s: float
    data_size_bits: float
    cpu_cycles: float
    deadline_s: float
    service_type: str

# %%
@dataclass
class ServiceProfile:
    name: str
    latency_budget_s: float
    energy_weight: float
    latency_weight: float
    task_data_bits_mean: float
    task_cpu_cycles_mean: float
    task_interarrival_s: float

# %%
SERVICE_PROFILES: Dict[str, ServiceProfile] = {
    "VR": ServiceProfile(
        name="VR",  # models eMBB (Enhanced Mobile Broadband) like (VR, AR, cloud gaming, video)
        latency_budget_s=0.05,  
        energy_weight=0.3,
        latency_weight=0.7,
        task_data_bits_mean=5e6,   # 5 Mbits
        task_cpu_cycles_mean=5e9, 
        task_interarrival_s=0.2    # task every ~200 ms
    ),
    "EV": ServiceProfile(
        name="EV",  # models URLLC (Ultra Reliable Low Latency Communication) like (EV control, robotics, remote surgery)
        latency_budget_s=0.1,  
        energy_weight=0.4,
        latency_weight=0.6,
        task_data_bits_mean=1e6,
        task_cpu_cycles_mean=2e9,
        task_interarrival_s=0.5
    ),
    "IoT": ServiceProfile(
        name="IoT",  # models mMTC (Massive Machine Type Communications) like (IoT sensors, smart meters)
        latency_budget_s=1.0,    
        energy_weight=0.75,
        latency_weight=0.3,
        task_data_bits_mean=1e5,
        task_cpu_cycles_mean=5e8,
        task_interarrival_s=5.0
    ),
}

# %%
@dataclass
class MecServer:
    id: int
    attached_bs: int
    cpu_ghz: float = 10.0

# %% [markdown]
# # Core simulation
# Simplified joint radio + MEC environment.
#
#     This class is intentionally generic and easy to control from
#     rule-based or learning-based agents.
#
#     Time is discrete: each step advances the simulation by dt_s seconds.

# %%
class NetworkSimulation:

    def __init__(
        self,
        num_cells: int = 3,
        area_size: Tuple[float, float] = (1000.0, 1000.0),
        dt_s: float = 0.1,
        seed: Optional[int] = None,
    ) -> None:
        self.num_cells = num_cells
        self.area_size = area_size
        self.dt_s = dt_s
        self.rng = random.Random(seed)
        #np.random.seed(seed if seed is not None else 907)

        self.base_stations: List[BaseStation] = []
        self.mec_servers: Dict[int, MecServer] = {}
        self.ue: Optional[UserEquipment] = None
        self.current_time_s: float = 0.0
        self.service_profile: ServiceProfile = SERVICE_PROFILES["VR"]
        self.serving_cell_id: int = 0
        self.task_counter: int = 0
        self.time_until_next_task_s: float = 0.0
        self.trace: List[Dict[str, Any]] = []

        self._init_cells_and_mec()

    # ------------------------ initialization -----------------------------

    def _init_cells_and_mec(self) -> None:
        """Place base stations in a simple line for now, each with a MEC server."""
        max_x, max_y = self.area_size
        spacing = max_x / (self.num_cells + 1)

        self.base_stations.clear()
        self.mec_servers.clear()

        for i in range(self.num_cells):
            bs_x = spacing * (i + 1)
            bs_y = max_y / 2.0
            bs = BaseStation(id=i, x=bs_x, y=bs_y)
            self.base_stations.append(bs)
            self.mec_servers[i] = MecServer(id=i, attached_bs=i)

    # ------------------------ public API ---------------------------------

    def reset(
        self,
        service_type: str = "VR",
        random_start: bool = True,
        seed: Optional[int] = None,
    ) -> Dict[str, Any]:
        """Reset simulation state and return initial context."""
        if seed is not None:
            self.rng.seed(seed)
            np.random.seed(seed)

        if service_type not in SERVICE_PROFILES:
            raise ValueError(f"Unknown service_type '{service_type}'")

        self.service_profile = SERVICE_PROFILES[service_type]
        self.current_time_s = 0.0
        self.task_counter = 0
        self.time_until_next_task_s = self._sample_interarrival()
        self.trace = []

        max_x, max_y = self.area_size

        if random_start:
            x = self.rng.uniform(0.1 * max_x, 0.9 * max_x)
            y = self.rng.uniform(0.1 * max_y, 0.9 * max_y)
            direction = self.rng.uniform(0, 2 * math.pi)
        else:
            x, y = max_x * 0.1, max_y / 2.0
            direction = 0.0

        speed_mps = 10.0  # ~36 km/h, can be tuned
        self.ue = UserEquipment(
            x=x,
            y=y,
            speed_mps=speed_mps,
            direction_rad=direction,
        )

        # Initial serving cell: max RSRP
        radio_state = self._compute_radio_state()
        self.serving_cell_id = int(np.argmax(radio_state["rsrp_dbm"]))

        return self.get_context()

    # ------------------------ radio model --------------------------------

    def _compute_radio_state(self) -> Dict[str, Any]:
        """Compute distances, RSRP, SINR and throughput per cell."""
        if self.ue is None:
            raise RuntimeError("Simulation not reset. Call reset() first.")

        rsrp_dbm_list: List[float] = []
        sinr_db_list: List[float] = []
        throughput_bps_list: List[float] = []

        ue_x, ue_y = self.ue.x, self.ue.y

        for bs in self.base_stations:
            d = bs.distance_to(ue_x, ue_y)
            pl_db = path_loss_db(d)
            rx_power_dbm = bs.tx_power_dbm - pl_db
            rsrp_dbm_list.append(rx_power_dbm)

        # For simplicity, treat interference as coming from all non-serving cells when computing SINR for each candidate cell
        for i, bs in enumerate(self.base_stations):
            signal_w = dbm_to_watts(rsrp_dbm_list[i])
            interference_w = 0.0
            for j, _ in enumerate(self.base_stations):
                if j == i:
                    continue
                interference_w += dbm_to_watts(rsrp_dbm_list[j])

            noise_w = dbm_to_watts(bs.noise_dbm)
            sinr_linear = signal_w / (interference_w + noise_w + 1e-15)
            sinr_db = 10 * math.log10(max(sinr_linear, 1e-15))
            sinr_db_list.append(sinr_db)

            bandwidth_hz = bs.bandwidth_mhz * 1e6
            capacity_bps = shannon_capacity_hz(bandwidth_hz, sinr_linear)
            throughput_bps_list.append(capacity_bps)

        return {
            "rsrp_dbm": rsrp_dbm_list,
            "sinr_db": sinr_db_list,
            "throughput_bps": throughput_bps_list,
        }

    # ------------------------ task model ---------------------------------

    def _sample_interarrival(self) -> float:
        """Sample time until next task using exponential distribution."""
        lam = 1.0 / self.service_profile.task_interarrival_s
        # Avoid extremely small intervals
        return max(np.random.exponential(1.0 / lam), 0.01)

    def _maybe_generate_task(self) -> Optional[Task]:
        if self.time_until_next_task_s > 0:
            return None

        self.task_counter += 1

        data_size = max(
            np.random.normal(self.service_profile.task_data_bits_mean,
                             0.3 * self.service_profile.task_data_bits_mean),
            1e4,
        )
        cpu_cycles = max(
            np.random.normal(self.service_profile.task_cpu_cycles_mean,
                             0.3 * self.service_profile.task_cpu_cycles_mean),
            1e7,
        )

        deadline = self.current_time_s + self.service_profile.latency_budget_s

        task = Task(
            id=self.task_counter,
            arrival_time_s=self.current_time_s,
            data_size_bits=data_size,
            cpu_cycles=cpu_cycles,
            deadline_s=deadline,
            service_type=self.service_profile.name,
        )

        # Schedule next task
        self.time_until_next_task_s = self._sample_interarrival()
        return task

    # ------------------------ context & decisions ------------------------

    def get_context(self) -> Dict[str, Any]:
        """Return the observable context for decision-making agents."""
        if self.ue is None:
            raise RuntimeError("Simulation not reset. Call reset() first.")

        radio_state = self._compute_radio_state()
        serving_idx = self.serving_cell_id
        rsrp_serving = radio_state["rsrp_dbm"][serving_idx]
        sinr_serving = radio_state["sinr_db"][serving_idx]
        throughput_serving = radio_state["throughput_bps"][serving_idx]

        context = {
            "time_s": self.current_time_s,
            "service_type": self.service_profile.name,
            "latency_budget_s": self.service_profile.latency_budget_s,
            "ue_position": (self.ue.x, self.ue.y),
            "ue_speed_mps": self.ue.speed_mps,
            "serving_cell_id": self.serving_cell_id,
            "rsrp_dbm": radio_state["rsrp_dbm"],
            "sinr_db": radio_state["sinr_db"],
            "throughput_bps": radio_state["throughput_bps"],
            "serving_rsrp_dbm": rsrp_serving,
            "serving_sinr_db": sinr_serving,
            "serving_throughput_bps": throughput_serving,
            "user_pref": {
                "latency_weight": self.service_profile.latency_weight,
                "energy_weight": self.service_profile.energy_weight,
            },
        }
        return context

    # ------------------------ task evaluation ----------------------------

    def _evaluate_task_decision(
        self,
        task: Task,
        offload_target: str,
        serving_throughput_bps: float,
    ) -> Dict[str, Any]:
        """Evaluate latency / energy for a single task given offload target."""
        ue = self.ue
        if ue is None:
            raise RuntimeError("Simulation not reset. Call reset() first.")

        # Parameters for a toy energy model
        tx_power_w = 1.0    # 1 Watt transmit
        cpu_power_w = 2.0   # 2 Watt while computing

        # Local processing
        if offload_target == "local":
            exec_time_s = task.cpu_cycles / (ue.local_cpu_ghz * 1e9)
            total_latency_s = exec_time_s
            energy_j = exec_time_s * cpu_power_w

        # Edge processing via serving cell
        elif offload_target == "edge":
            tx_rate_bps = max(serving_throughput_bps, 1e3)
            tx_time_s = task.data_size_bits / tx_rate_bps
            mec = self.mec_servers[self.serving_cell_id]
            exec_time_s = task.cpu_cycles / (mec.cpu_ghz * 1e9)
            total_latency_s = tx_time_s + exec_time_s
            energy_j = tx_time_s * tx_power_w

        # "Cloud" with extra backhaul latency
        elif offload_target == "cloud":
            tx_rate_bps = max(serving_throughput_bps, 1e3)
            tx_time_s = task.data_size_bits / tx_rate_bps
            backhaul_s = 0.02  # 20 ms backbone delay (toy)
            cloud_cpu_ghz = 50.0
            exec_time_s = task.cpu_cycles / (cloud_cpu_ghz * 1e9)
            total_latency_s = tx_time_s + backhaul_s + exec_time_s
            energy_j = tx_time_s * tx_power_w

        else:
            raise ValueError(f"Unknown offload_target '{offload_target}'")

        deadline_met = total_latency_s <= (task.deadline_s - task.arrival_time_s)

        # Update UE battery
        ue.battery_joules -= energy_j

        return {
            "task_id": task.id,
            "offload_target": offload_target,
            "latency_s": total_latency_s,
            "deadline_s": task.deadline_s - task.arrival_time_s,
            "deadline_met": deadline_met,
            "energy_j": energy_j,
        }

    # ------------------------ baseline controller ------------------------

    def baseline_controller(self, context: Dict[str, Any]) -> Dict[str, Any]:
        """Simple rule-based controller for both HO and offloading.

        - Handover to the cell with highest RSRP if it's better than the
          current one by > hysteresis_db.
        - Offload locally for small tasks / bad channel, edge otherwise.
        - Cloud is unused in this simple baseline.
        """
        rsrp_list = context["rsrp_dbm"]
        serving_idx = context["serving_cell_id"] 
        serving_rsrp = rsrp_list[serving_idx]
        best_idx = int(np.argmax(rsrp_list))
        best_rsrp = rsrp_list[best_idx]

        hysteresis_db = 5.0 #at least 5 dB better to trigger HO
        target_cell = serving_idx
        if best_idx != serving_idx and (best_rsrp - serving_rsrp) > hysteresis_db: 
            target_cell = best_idx 

        # Offloading rule: here we simply look at serving throughput and latency budget.
        thr = context["serving_throughput_bps"]
        latency_budget_s = context["latency_budget_s"]

        if latency_budget_s < 0.07 and thr > 5e6: 
            offload_target = "edge"
        elif latency_budget_s < 0.2 and thr > 2e6: 
            offload_target = "edge"
        else:
            offload_target = "local"

        return {
            "handover_target": target_cell,
            "offload_target": offload_target,
        }

    # ------------------------ main stepping logic ------------------------

    def step(self, decision: Optional[Dict[str, Any]] = None) -> Tuple[Dict[str, Any], Dict[str, Any]]:
        """Advance the simulation by one time step.

        decision:
            {
              "handover_target": Optional[int],  # target cell index
              "offload_target": Optional[str],   # "local" | "edge" | "cloud" | None
            }
        If decision is None, use the baseline_controller.

        Returns:
            next_context, info

        info contains any generated task metrics and misc diagnostics.
        """
        if self.ue is None:
            raise RuntimeError("Simulation not reset. Call reset() first.")

        # Use baseline controller if none provided
        if decision is None:
            decision = self.baseline_controller(self.get_context())

        # 1) Apply handover decision (if any)
        ho_target = decision.get("handover_target", self.serving_cell_id)
        if not isinstance(ho_target, int) or ho_target < 0 or ho_target >= self.num_cells:
            ho_target = self.serving_cell_id
        self.serving_cell_id = ho_target

        # 2) Move UE
        self.ue.step(self.dt_s, self.area_size)

        # 3) Time & task arrival
        self.current_time_s += self.dt_s
        self.time_until_next_task_s -= self.dt_s

        new_task = self._maybe_generate_task()

        # 4) Compute new radio state
        radio_state = self._compute_radio_state()
        serving_thr = radio_state["throughput_bps"][self.serving_cell_id]

        # 5) Evaluate offloading decision if there's a task and a target
        task_info: Optional[Dict[str, Any]] = None
        if new_task is not None:
            offload_target = decision.get("offload_target", "local")
            if offload_target is None:
                offload_target = "local"
            task_info = self._evaluate_task_decision(new_task, offload_target, serving_thr)

        # 6) Build context & log
        context = self.get_context()
        info: Dict[str, Any] = {
            "decision": decision,
            "new_task": new_task is not None,
            "task_info": task_info,
        }

        log_entry = {
            "time_s": self.current_time_s,
            "context": context,
            "decision": decision,
            "task_info": task_info,
        }
        self.trace.append(log_entry)

        return context, info

    # ------------------------ rollouts -----------------------------------

    def run_episode(
        self,
        num_steps: int,
        controller_fn: Optional[Any] = None,
    ) -> List[Dict[str, Any]]:
        """Run a full episode and return the collected trace.

        controller_fn: callable taking context and returning a decision dict.
                       If None, uses baseline_controller.
        """
        self.trace = []
        for _ in range(num_steps):
            ctx = self.get_context()
            if controller_fn is None:
                decision = None
            else:
                decision = controller_fn(ctx)
            self.step(decision)
        return self.trace

# %% [markdown]
# # Minimal smoke test

# %%
sim = NetworkSimulation(num_cells=3, area_size=(1000.0, 1000.0), dt_s=0.01, seed=907)
ctx = sim.reset(service_type="VR")
print("Initial context:")
print({k: v for k, v in ctx.items() if k not in ("rsrp_dbm", "sinr_db", "throughput_bps")})

trace = sim.run_episode(num_steps=5000)
num_tasks = sum(1 for t in trace if t["task_info"] is not None)
print(f"Ran 50 steps, tasks generated: {num_tasks}")
# Out:
# Initial context:
# {'time_s': 0.0, 'service_type': 'VR', 'latency_budget_s': 0.05, 'ue_position': (661.2577104736738, 143.01620664673152), 'ue_speed_mps': 10.0, 'serving_cell_id': 2, 'serving_rsrp_dbm': -73.79842045548558, 'serving_sinr_db': -0.24570621668202625, 'serving_throughput_bps': 19195324.658412267, 'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}}
# Ran 50 steps, tasks generated: 237

# %%
trace
# Out:
# [{'time_s': 0.01,
#   'context': {'time_s': 0.01,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.3144926777114, 143.09852178084813),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.76192587227486, -74.75199485889658, -73.7945530055611],
#    'sinr_db': [-8.531110687957602, -1.94561813027782, -0.2434322676171385],
#    'throughput_bps': [3786889.4996662717,
#     14254693.81814482,
#     19202665.914297745],
#    'serving_rsrp_dbm': -73.7945530055611,
#    'serving_sinr_db': -0.2434322676171385,
#    'serving_throughput_bps': 19202665.914297745,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.02,
#   'context': {'time_s': 0.02,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.3712748817491, 143.18083691496474),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.76161740657318, -74.74999165576003, -73.79068471111715],
#    'sinr_db': [-8.533836377143547, -1.9467584165241196, -0.24115712503958242],
#    'throughput_bps': [3784662.7694648877,
#     14251740.685280602,
#     19210013.000938434],
#    'serving_rsrp_dbm': -73.79068471111715,
#    'serving_sinr_db': -0.24115712503958242,
#    'serving_throughput_bps': 19210013.000938434,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.03,
#   'context': {'time_s': 0.03,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.4280570857867, 143.26315204908136),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7613094409501, -74.74798891590127, -73.7868155718661],
#    'sinr_db': [-8.536563029301448, -1.9479002120409838, -0.2388807882459163],
#    'throughput_bps': [3782436.478613147,
#     14248784.117737394,
#     19217365.923748896],
#    'serving_rsrp_dbm': -73.7868155718661,
#    'serving_sinr_db': -0.2388807882459163,
#    'serving_throughput_bps': 19217365.923748896,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.04,
#   'context': {'time_s': 0.04,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.4848392898243, 143.34546718319797),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.76100197546694, -74.74598663982586, -73.78294558752026],
#    'sinr_db': [-8.539290644833486, -1.9490435178543004, -0.23660325653229464],
#    'throughput_bps': [3780210.627501345,
#     14245824.114712968,
#     19224724.68814888],
#    'serving_rsrp_dbm': -73.78294558752026,
#    'serving_sinr_db': -0.23660325653229464,
#    'serving_throughput_bps': 19224724.68814888,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.05,
#   'context': {'time_s': 0.05,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.541621493862, 143.42778231731458),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.76069501018492, -74.74398482803949, -73.77907475779186],
#    'sinr_db': [-8.542019224142267, -1.9501883349900884, -0.23432452919455807],
#    'throughput_bps': [3777985.21651956, 14242860.67540871, 19232089.299563054],
#    'serving_rsrp_dbm': -73.77907475779186,
#    'serving_sinr_db': -0.23432452919455807,
#    'serving_throughput_bps': 19232089.299563054,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.060000000000000005,
#   'context': {'time_s': 0.060000000000000005,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.5984036978996, 143.5100974514312),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.76038854516511, -74.74198348104812, -73.77520308239308],
#    'sinr_db': [-8.54474876763076, -1.9513346644745444, -0.2320446055282247],
#    'throughput_bps': [3775760.246057694, 14239893.79902953, 19239459.76342105],
#    'serving_rsrp_dbm': -73.77520308239308,
#    'serving_sinr_db': -0.2320446055282247,
#    'serving_throughput_bps': 19239459.76342105,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.07,
#   'context': {'time_s': 0.07,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.6551859019372, 143.5924125855478),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.76008258046858, -74.73998259935792, -73.77133056103601],
#    'sinr_db': [-8.547479275702415, -1.9524825073340608, -0.22976348482840686],
#    'throughput_bps': [3773535.716505369, 14236923.48478379, 19246836.0851577],
#    'serving_rsrp_dbm': -73.77133056103601,
#    'serving_sinr_db': -0.22976348482840686,
#    'serving_throughput_bps': 19246836.0851577,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.08,
#   'context': {'time_s': 0.08,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.7119681059748, 143.67472771966442),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75977711615622, -74.73798218347522, -73.76745719343273],
#    'sinr_db': [-8.550210748761094, -1.953631864595057, -0.2274811663900185],
#    'throughput_bps': [3771311.628252011,
#     14233949.731883768,
#     19254218.270212412],
#    'serving_rsrp_dbm': -73.76745719343273,
#    'serving_sinr_db': -0.2274811663900185,
#    'serving_throughput_bps': 19254218.270212412,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 1,
#    'offload_target': 'edge',
#    'latency_s': 0.4462579567423879,
#    'deadline_s': 0.05,
#    'deadline_met': False,
#    'energy_j': 0.2615559673319193}},
#  {'time_s': 0.09,
#   'context': {'time_s': 0.09,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.7687503100125, 143.75704285378103),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75947215228888, -74.7359822339067, -73.76358297929521],
#    'sinr_db': [-8.552943187211017, -1.9547827372843172, -0.225197649507466],
#    'throughput_bps': [3769087.9816868757,
#     14230972.539544772,
#     19261606.324030153],
#    'serving_rsrp_dbm': -73.76358297929521,
#    'serving_sinr_db': -0.225197649507466,
#    'serving_throughput_bps': 19261606.324030153,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 2,
#    'offload_target': 'edge',
#    'latency_s': 0.9275641934526151,
#    'deadline_s': 0.05000000000000002,
#    'deadline_met': False,
#    'energy_j': 0.31744009593793937}},
#  {'time_s': 0.09999999999999999,
#   'context': {'time_s': 0.09999999999999999,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.8255325140501, 143.83935798789764),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75916768892728, -74.7339827511591, -73.75970791833538],
#    'sinr_db': [-8.555676591456864, -1.9559351264285882, -0.22291293347498503],
#    'throughput_bps': [3766864.777198952, 14227991.9069862, 19269000.252060354],
#    'serving_rsrp_dbm': -73.75970791833538,
#    'serving_sinr_db': -0.22291293347498503,
#    'serving_throughput_bps': 19269000.252060354,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.10999999999999999,
#   'context': {'time_s': 0.10999999999999999,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.8823147180877, 143.92167312201425),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75886372613208, -74.73198373573949, -73.75583201026505],
#    'sinr_db': [-8.558410961903801, -1.9570890330549444, -0.22062701758628983],
#    'throughput_bps': [3764642.015176971,
#     14225007.833430594,
#     19276400.059758063],
#    'serving_rsrp_dbm': -73.75583201026505,
#    'serving_sinr_db': -0.22062701758628983,
#    'serving_throughput_bps': 19276400.059758063,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.11999999999999998,
#   'context': {'time_s': 0.11999999999999998,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.9390969221254, 144.00398825613087),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75856026396382, -74.72998518815511, -73.75195525479607],
#    'sinr_db': [-8.561146298957286, -1.9582444581904879, -0.21833990113493795],
#    'throughput_bps': [3762419.6960095474,
#     14222020.318104416,
#     19283805.752582762],
#    'serving_rsrp_dbm': -73.75195525479607,
#    'serving_sinr_db': -0.21833990113493795,
#    'serving_throughput_bps': 19283805.752582762,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.12999999999999998,
#   'context': {'time_s': 0.12999999999999998,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (661.995879126163, 144.08630339024748),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75825730248295, -74.72798710891342, -73.74807765164013],
#    'sinr_db': [-8.563882603023291, -1.9594014028625752, -0.21605158341401676],
#    'throughput_bps': [3760197.8200849975,
#     14219029.360237475,
#     19291217.335999392],
#    'serving_rsrp_dbm': -73.74807765164013,
#    'serving_sinr_db': -0.21605158341401676,
#    'serving_throughput_bps': 19291217.335999392,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 3,
#    'offload_target': 'edge',
#    'latency_s': 0.9135437291034051,
#    'deadline_s': 0.05000000000000002,
#    'deadline_met': False,
#    'energy_j': 0.2821474536335965}},
#  {'time_s': 0.13999999999999999,
#   'context': {'time_s': 0.13999999999999999,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.0526613302006, 144.1686185243641),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75795484174984, -74.72598949852211, -73.74419920050893],
#    'sinr_db': [-8.56661987450818, -1.9605598680986038, -0.21376206371640286],
#    'throughput_bps': [3757976.387791443,
#     14216034.959063483,
#     19298634.815477494],
#    'serving_rsrp_dbm': -73.74419920050893,
#    'serving_sinr_db': -0.21376206371640286,
#    'serving_throughput_bps': 19298634.815477494,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.15,
#   'context': {'time_s': 0.15,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.1094435342383, 144.2509336584807),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75765288182477, -74.72399235748908, -73.74031990111403],
#    'sinr_db': [-8.569358113818746, -1.9617198549263093, -0.2114713413344628],
#    'throughput_bps': [3755755.399516797,
#     14213037.113819279,
#     19306058.19649222],
#    'serving_rsrp_dbm': -73.74031990111403,
#    'serving_sinr_db': -0.2114713413344628,
#    'serving_throughput_bps': 19306058.19649222,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.16,
#   'context': {'time_s': 0.16,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.1662257382759, 144.33324879259732),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75735142276787, -74.7219956863224, -73.73643975316702],
#    'sinr_db': [-8.572097321362177, -1.9628813643733642, -0.20917941556044195],
#    'throughput_bps': [3753534.855648744, 14210035.82374589, 19313487.48452303],
#    'serving_rsrp_dbm': -73.73643975316702,
#    'serving_sinr_db': -0.20917941556044195,
#    'serving_throughput_bps': 19313487.48452303,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.17,
#   'context': {'time_s': 0.17,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.2230079423135, 144.41556392671393),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75705046463926, -74.7199994855305, -73.73255875637935],
#    'sinr_db': [-8.574837497546115, -1.9640443974678257, -0.20688628568602568],
#    'throughput_bps': [3751314.756574759,
#     14207031.088087372,
#     19320922.685055178],
#    'serving_rsrp_dbm': -73.73255875637935,
#    'serving_sinr_db': -0.20688628568602568,
#    'serving_throughput_bps': 19320922.685055178,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.18000000000000002,
#   'context': {'time_s': 0.18000000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.2797901463512, 144.49787906083054),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75675000749892, -74.71800375562181, -73.72867691046243],
#    'sinr_db': [-8.577578642778652, -1.9652089552376792, -0.20459195100276384],
#    'throughput_bps': [3749095.1026820443,
#     14204022.906091975,
#     19328363.803578258],
#    'serving_rsrp_dbm': -73.72867691046243,
#    'serving_sinr_db': -0.20459195100276384,
#    'serving_throughput_bps': 19328363.803578258,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.19000000000000003,
#   'context': {'time_s': 0.19000000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.3365723503888, 144.58019419494715),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75645005140673, -74.71600849710516, -73.72479421512762],
#    'sinr_db': [-8.580320757468243, -1.9663750387112406, -0.20229641080173055],
#    'throughput_bps': [3746875.894357663, 14201011.27701114, 19335810.8455874],
#    'serving_rsrp_dbm': -73.72479421512762,
#    'serving_sinr_db': -0.20229641080173055,
#    'serving_throughput_bps': 19335810.8455874,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.20000000000000004,
#   'context': {'time_s': 0.20000000000000004,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.3933545544264, 144.66250932906377),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75615059642249, -74.71401371048952, -73.72091067008621],
#    'sinr_db': [-8.583063842023753, -1.9675426489168948, -0.1999996643737527],
#    'throughput_bps': [3744657.131988453,
#     14197996.200100156,
#     19343263.816582456],
#    'serving_rsrp_dbm': -73.72091067008621,
#    'serving_sinr_db': -0.1999996643737527,
#    'serving_throughput_bps': 19343263.816582456,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.21000000000000005,
#   'context': {'time_s': 0.21000000000000005,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.450136758464, 144.74482446318038),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75585164260589, -74.71201939628409, -73.71702627504945],
#    'sinr_db': [-8.58580789685457, -1.96871178688323, -0.19770171100923029],
#    'throughput_bps': [3742438.815960949,
#     14194977.674617836,
#     19350722.722068638],
#    'serving_rsrp_dbm': -73.71702627504945,
#    'serving_sinr_db': -0.19770171100923029,
#    'serving_throughput_bps': 19350722.722068638,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.22000000000000006,
#   'context': {'time_s': 0.22000000000000006,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.5069189625017, 144.827139597297),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75555319001653, -74.71002555499827, -73.71314102972848],
#    'sinr_db': [-8.588552922370399, -1.9698824536389186, -0.195402549998345],
#    'throughput_bps': [3740220.9466615706,
#     14191955.699826807,
#     19358187.567555815],
#    'serving_rsrp_dbm': -73.71314102972848,
#    'serving_sinr_db': -0.195402549998345,
#    'serving_throughput_bps': 19358187.567555815,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.23000000000000007,
#   'context': {'time_s': 0.23000000000000007,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.5637011665393, 144.9094547314136),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75525523871396, -74.70803218714165, -73.7092549338344],
#    'sinr_db': [-8.591298918981465, -1.9710546502128345, -0.19310218063084889],
#    'throughput_bps': [3738003.5244764304,
#     14188930.274993232,
#     19365658.358559225],
#    'serving_rsrp_dbm': -73.7092549338344,
#    'serving_sinr_db': -0.19310218063084889,
#    'serving_throughput_bps': 19365658.358559225,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.24000000000000007,
#   'context': {'time_s': 0.24000000000000007,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.620483370577, 144.99176986553022),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75495778875757, -74.70603929322414, -73.70536798707829],
#    'sinr_db': [-8.594045887098359, -1.9722283776340106, -0.1908006021961856],
#    'throughput_bps': [3735786.5497914744,
#     14185901.39938692,
#     19373135.100599065],
#    'serving_rsrp_dbm': -73.70536798707829,
#    'serving_sinr_db': -0.1908006021961856,
#    'serving_throughput_bps': 19373135.100599065,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.25000000000000006,
#   'context': {'time_s': 0.25000000000000006,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.6772655746146, 145.07408499964683),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75466084020667, -74.70404687375573, -73.7014801891711],
#    'sinr_db': [-8.596793827132077, -1.9734036369315877, -0.1884978139835094],
#    'throughput_bps': [3733570.0229924424,
#     14182869.072281448,
#     19380617.79920043],
#    'serving_rsrp_dbm': -73.7014801891711,
#    'serving_sinr_db': -0.1884978139835094,
#    'serving_throughput_bps': 19380617.79920043,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 4,
#    'offload_target': 'edge',
#    'latency_s': 0.6940474773251166,
#    'deadline_s': 0.04999999999999999,
#    'deadline_met': False,
#    'energy_j': 0.15865363434617236}},
#  {'time_s': 0.26000000000000006,
#   'context': {'time_s': 0.26000000000000006,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.7340477786522, 145.15640013376344),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75436439312051, -74.70205492924671, -73.69759153982375],
#    'sinr_db': [-8.59954273949414, -1.9745804291348832, -0.186193815281579],
#    'throughput_bps': [3731353.944464772,
#     14179833.29295401,
#     19388106.459893692],
#    'serving_rsrp_dbm': -73.69759153982375,
#    'serving_sinr_db': -0.186193815281579,
#    'serving_throughput_bps': 19388106.459893692,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.2700000000000001,
#   'context': {'time_s': 0.2700000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.7908299826898, 145.23871526788005),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75406844755823, -74.70006346020759, -73.6937020387471],
#    'sinr_db': [-8.602292624596389, -1.975758755273385, -0.18388860537883567],
#    'throughput_bps': [3729138.3145937906,
#     14176794.060685428,
#     19395601.08821422],
#    'serving_rsrp_dbm': -73.6937020387471,
#    'serving_sinr_db': -0.18388860537883567,
#    'serving_throughput_bps': 19395601.08821422,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.2800000000000001,
#   'context': {'time_s': 0.2800000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.8476121867275, 145.32103040199667),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75377300357884, -74.69807246714902, -73.68981168565197],
#    'sinr_db': [-8.605043482851167, -1.9769386163766827, -0.18158218356341374],
#    'throughput_bps': [3726923.1337645175,
#     14173751.374760335,
#     19403101.689702358],
#    'serving_rsrp_dbm': -73.68981168565197,
#    'serving_sinr_db': -0.18158218356341374,
#    'serving_throughput_bps': 19403101.689702358,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 5,
#    'offload_target': 'edge',
#    'latency_s': 0.6279150009545383,
#    'deadline_s': 0.04999999999999999,
#    'deadline_met': False,
#    'energy_j': 0.2943783270375891}},
#  {'time_s': 0.2900000000000001,
#   'context': {'time_s': 0.2900000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.9043943907651, 145.40334553611328),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75347806124134, -74.69608195058194, -73.68592048024907],
#    'sinr_db': [-8.607795314671234, -1.97812001347455, -0.17927454912307347],
#    'throughput_bps': [3724708.402361776,
#     14170705.234466953,
#     19410608.269903645],
#    'serving_rsrp_dbm': -73.68592048024907,
#    'serving_sinr_db': -0.17927454912307347,
#    'serving_throughput_bps': 19410608.269903645,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.3000000000000001,
#   'context': {'time_s': 0.3000000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (662.9611765948027, 145.4856606702299),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75318362060452, -74.69409191101747, -73.6820284222491],
#    'sinr_db': [-8.610548120469712, -1.979302947596854, -0.17696570134532869],
#    'throughput_bps': [3722494.1207702276,
#     14167655.639097363,
#     19418120.834368408],
#    'serving_rsrp_dbm': -73.6820284222491,
#    'serving_sinr_db': -0.17696570134532869,
#    'serving_throughput_bps': 19418120.834368408,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.3100000000000001,
#   'context': {'time_s': 0.3100000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.0179587988404, 145.5679758043465),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75288968172715, -74.69210234896693, -73.67813551136265],
#    'sinr_db': [-8.613301900660238, -1.980487419773696, -0.17465563951723934],
#    'throughput_bps': [3720280.2893742383,
#     14164602.587947115,
#     19425639.388652436],
#    'serving_rsrp_dbm': -73.67813551136265,
#    'serving_sinr_db': -0.17465563951723934,
#    'serving_throughput_bps': 19425639.388652436,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.3200000000000001,
#   'context': {'time_s': 0.3200000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.074741002878, 145.65029093846312),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75259624466791, -74.69011326494189, -73.67424174730029],
#    'sinr_db': [-8.616056655656827, -1.9816734310352597, -0.1723443629256148],
#    'throughput_bps': [3718066.908557992,
#     14161546.080315653,
#     19433163.938316334],
#    'serving_rsrp_dbm': -73.67424174730029,
#    'serving_sinr_db': -0.1723443629256148,
#    'serving_throughput_bps': 19433163.938316334,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.3300000000000001,
#   'context': {'time_s': 0.3300000000000001,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.1315232069156, 145.73260607257973),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75230330948537, -74.68812465945412, -73.67034712977251],
#    'sinr_db': [-8.618812385873989, -1.9828609824119052, -0.17003187085687585],
#    'throughput_bps': [3715853.978705411,
#     14158486.115506042,
#     19440694.488925952],
#    'serving_rsrp_dbm': -73.67034712977251,
#    'serving_sinr_db': -0.17003187085687585,
#    'serving_throughput_bps': 19440694.488925952,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.34000000000000014,
#   'context': {'time_s': 0.34000000000000014,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.1883054109533, 145.81492120669634),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75201087623796, -74.6861365330156, -73.66645165848973],
#    'sinr_db': [-8.621569091726538, -1.9840500749341232, -0.16771816259717867],
#    'throughput_bps': [3713641.500200289,
#     14155422.692825133,
#     19448231.046052005],
#    'serving_rsrp_dbm': -73.66645165848973,
#    'serving_sinr_db': -0.16771816259717867,
#    'serving_throughput_bps': 19448231.046052005,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.35000000000000014,
#   'context': {'time_s': 0.35000000000000014,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.2450876149909, 145.89723634081295),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75171894498408, -74.6841488861385, -73.66255533316236],
#    'sinr_db': [-8.624326773629836, -1.985240709632522, -0.16540323743232543],
#    'throughput_bps': [3711429.4734261143,
#     14152355.811583566,
#     19455773.615270354],
#    'serving_rsrp_dbm': -73.66255533316236,
#    'serving_sinr_db': -0.16540323743232543,
#    'serving_throughput_bps': 19455773.615270354,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.36000000000000015,
#   'context': {'time_s': 0.36000000000000015,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.3018698190285, 145.97955147492956),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75142751578203, -74.68216171933524, -73.65865815350065],
#    'sinr_db': [-8.627085431999694, -1.9864328875379014, -0.16308709464772786],
#    'throughput_bps': [3709217.8987661423,
#     14149285.471095603,
#     19463322.202162147],
#    'serving_rsrp_dbm': -73.65865815350065,
#    'serving_sinr_db': -0.16308709464772786,
#    'serving_throughput_bps': 19463322.202162147,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.37000000000000016,
#   'context': {'time_s': 0.37000000000000016,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.3586520230662, 146.06186660904618),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.75113658868997, -74.68017503311843, -73.65476011921493],
#    'sinr_db': [-8.629845067252242, -1.9876266096811792, -0.16076973352854568],
#    'throughput_bps': [3707006.776603486,
#     14146211.670679307,
#     19470876.812313344],
#    'serving_rsrp_dbm': -73.65476011921493,
#    'serving_sinr_db': -0.16076973352854568,
#    'serving_throughput_bps': 19470876.812313344,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.38000000000000017,
#   'context': {'time_s': 0.38000000000000017,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.4154342271038, 146.1441817431628),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.750846163766, -74.6781888280009, -73.65086123001534],
#    'sinr_db': [-8.632605679804117, -1.988821877093394, -0.15845115335959248],
#    'throughput_bps': [3704796.1073209983,
#     14143134.409656571,
#     19478437.451315053],
#    'serving_rsrp_dbm': -73.65086123001534,
#    'serving_sinr_db': -0.15845115335959248,
#    'serving_throughput_bps': 19478437.451315053,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.3900000000000002,
#   'context': {'time_s': 0.3900000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.4722164311414, 146.2264968772794),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7505562410681, -74.67620310449571, -73.64696148561201],
#    'sinr_db': [-8.635367270072358, -1.9900186908058188, -0.1561313534252725],
#    'throughput_bps': [3702585.8913013153,
#     14140053.68735279,
#     19486004.124763727],
#    'serving_rsrp_dbm': -73.64696148561201,
#    'serving_sinr_db': -0.1561313534252725,
#    'serving_throughput_bps': 19486004.124763727,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.4000000000000002,
#   'context': {'time_s': 0.4000000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.528998635179, 146.30881201139601),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7502668206542, -74.67421786311608, -73.64306088571504],
#    'sinr_db': [-8.638129838474505, -1.9912170518496963, -0.15381033300980204],
#    'throughput_bps': [3700376.1289268183,
#     14136969.503097573,
#     19493576.83826045],
#    'serving_rsrp_dbm': -73.64306088571504,
#    'serving_sinr_db': -0.15381033300980204,
#    'serving_throughput_bps': 19493576.83826045,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.4100000000000002,
#   'context': {'time_s': 0.4100000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.5857808392167, 146.39112714551263),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74997790258207, -74.6722331043755, -73.63915943003444],
#    'sinr_db': [-8.640893385428411, -1.9924169612565996, -0.15148809139693137],
#    'throughput_bps': [3698166.820579758,
#     14133881.856223814,
#     19501155.59741183],
#    'serving_rsrp_dbm': -73.63915943003444,
#    'serving_sinr_db': -0.15148809139693137,
#    'serving_throughput_bps': 19501155.59741183,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.4200000000000002,
#   'context': {'time_s': 0.4200000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.6425630432543, 146.47344227962924),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74968948690945, -74.67024882878763, -73.63525711828015],
#    'sinr_db': [-8.643657911352493, -1.993618420058134, -0.1491646278701288],
#    'throughput_bps': [3695957.966642048,
#     14130790.746068465,
#     19508740.407829434],
#    'serving_rsrp_dbm': -73.63525711828015,
#    'serving_sinr_db': -0.1491646278701288,
#    'serving_throughput_bps': 19508740.407829434,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 6,
#    'offload_target': 'edge',
#    'latency_s': 0.9900907781123128,
#    'deadline_s': 0.04999999999999999,
#    'deadline_met': False,
#    'energy_j': 0.45250165554259614}},
#  {'time_s': 0.4300000000000002,
#   'context': {'time_s': 0.4300000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.699345247292, 146.55575741374585),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74940157369394, -74.66826503686639, -73.6313539501621],
#    'sinr_db': [-8.646423416665508, -1.9948214292860071, -0.14683994171260897],
#    'throughput_bps': [3693749.567495478,
#     14127696.171972351,
#     19516331.275129672],
#    'serving_rsrp_dbm': -73.6313539501621,
#    'serving_sinr_db': -0.14683994171260897,
#    'serving_throughput_bps': 19516331.275129672,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.4400000000000002,
#   'context': {'time_s': 0.4400000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.7561274513296, 146.63807254786246),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74911416299308, -74.66628172912583, -73.62744992539008],
#    'sinr_db': [-8.649189901786732, -1.996025989972162, -0.14451403220712783],
#    'throughput_bps': [3691541.623521541, 14124598.13327985, 19523928.20493448],
#    'serving_rsrp_dbm': -73.62744992539008,
#    'serving_sinr_db': -0.14451403220712783,
#    'serving_throughput_bps': 19523928.20493448,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.45000000000000023,
#   'context': {'time_s': 0.45000000000000023,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.8129096553672, 146.72038768197908),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74882725486425, -74.66429890608029, -73.6235450436739],
#    'sinr_db': [-8.651957367135761, -1.997232103148663, -0.14218689863617792],
#    'throughput_bps': [3689334.1351016033,
#     14121496.629339168,
#     19531531.20287069],
#    'serving_rsrp_dbm': -73.6235450436739,
#    'serving_sinr_db': -0.14218689863617792,
#    'serving_throughput_bps': 19531531.20287069,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.46000000000000024,
#   'context': {'time_s': 0.46000000000000024,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.8696918594048, 146.8027028160957),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74854084936483, -74.66231656824431, -73.61963930472326],
#    'sinr_db': [-8.654725813132767, -1.998439769847651, -0.13985854028192185],
#    'throughput_bps': [3687127.1026166957,
#     14118391.659502476,
#     19539140.274570238],
#    'serving_rsrp_dbm': -73.61963930472326,
#    'serving_sinr_db': -0.13985854028192185,
#    'serving_throughput_bps': 19539140.274570238,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.47000000000000025,
#   'context': {'time_s': 0.47000000000000025,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.9264740634425, 146.8850179502123),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74825494655201, -74.66033471613258, -73.61573270824783],
#    'sinr_db': [-8.657495240198237, -1.999648991101453, -0.13752895642619412],
#    'throughput_bps': [3684920.5264477297,
#     14115283.223125644,
#     19546755.425670173],
#    'serving_rsrp_dbm': -73.61573270824783,
#    'serving_sinr_db': -0.13752895642619412,
#    'serving_throughput_bps': 19546755.425670173,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.48000000000000026,
#   'context': {'time_s': 0.48000000000000026,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (663.9832562674801, 146.9673330843289),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74796954648296, -74.65835335026009, -73.61182525395724],
#    'sinr_db': [-8.66026564875316, -2.0008597679425035, -0.13519814635050256],
#    'throughput_bps': [3682714.406975341,
#     14112171.319568409,
#     19554376.661812656],
#    'serving_rsrp_dbm': -73.61182525395724,
#    'serving_sinr_db': -0.13519814635050256,
#    'serving_throughput_bps': 19554376.661812656,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.49000000000000027,
#   'context': {'time_s': 0.49000000000000027,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.0400384715177, 147.04964821844553),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7476846492147, -74.65637247114196, -73.60791694156097],
#    'sinr_db': [-8.663037039218969, -2.0020721014034004, -0.1328661093359963],
#    'throughput_bps': [3680508.7445799415,
#     14109055.948194278,
#     19562003.988645054],
#    'serving_rsrp_dbm': -73.60791694156097,
#    'serving_sinr_db': -0.1328661093359963,
#    'serving_throughput_bps': 19562003.988645054,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5000000000000002,
#   'context': {'time_s': 0.5000000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.0968206755554, 147.13196335256214),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74740025480419, -74.65439207929354, -73.60400777076858],
#    'sinr_db': [-8.665809412017477, -2.003285992516785, -0.1305328446636069],
#    'throughput_bps': [3678303.539641775, 14105937.108370818, 19569637.4118195],
#    'serving_rsrp_dbm': -73.60400777076858,
#    'serving_sinr_db': -0.1305328446636069,
#    'serving_throughput_bps': 19569637.4118195,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5100000000000002,
#   'context': {'time_s': 0.5100000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.153602879593, 147.21427848667875),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74711636330828, -74.65241217523045, -73.60009774128943],
#    'sinr_db': [-8.668582767571015, -2.004501442315631, -0.12819835161371632],
#    'throughput_bps': [3676098.792540784,
#     14102814.79946892,
#     19577276.936993968],
#    'serving_rsrp_dbm': -73.60009774128943,
#    'serving_sinr_db': -0.12819835161371632,
#    'serving_throughput_bps': 19577276.936993968,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5200000000000002,
#   'context': {'time_s': 0.5200000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.2103850836306, 147.29659362079536),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74683297478374, -74.65043275946846, -73.59618685283294],
#    'sinr_db': [-8.671357106302338, -2.005718451832831, -0.12586262946658866],
#    'throughput_bps': [3673894.5036567287,
#     14099689.020863865,
#     19584922.569830872],
#    'serving_rsrp_dbm': -73.59618685283294,
#    'serving_sinr_db': -0.12586262946658866,
#    'serving_throughput_bps': 19584922.569830872,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5300000000000002,
#   'context': {'time_s': 0.5300000000000002,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.2671672876683, 147.37890875491198),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74655008928718, -74.64845383252354, -73.5922751051084],
#    'sinr_db': [-8.67413242863451, -2.0069370221015506, -0.12352567750208092],
#    'throughput_bps': [3671690.673369226,
#     14096559.771934438,
#     19592574.315998014],
#    'serving_rsrp_dbm': -73.5922751051084,
#    'serving_sinr_db': -0.12352567750208092,
#    'serving_throughput_bps': 19592574.315998014,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5400000000000003,
#   'context': {'time_s': 0.5400000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.3239494917059, 147.4612238890286),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74626770687523, -74.6464753949119, -73.58836249782507],
#    'sinr_db': [-8.676908734991255, -2.00815715415496, -0.12118749499975234],
#    'throughput_bps': [3669487.302057509, 14093427.0520636, 19600232.181168236],
#    'serving_rsrp_dbm': -73.58836249782507,
#    'serving_sinr_db': -0.12118749499975234,
#    'serving_throughput_bps': 19600232.181168236,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5500000000000003,
#   'context': {'time_s': 0.5500000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.3807316957435, 147.5435390231452),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74598582760433, -74.64449744714997, -73.58444903069216],
#    'sinr_db': [-8.67968602579656, -2.009378849026495, -0.11884808123878146],
#    'throughput_bps': [3667284.390100733,
#     14090290.860637827,
#     19607896.171019677],
#    'serving_rsrp_dbm': -73.58444903069216,
#    'serving_sinr_db': -0.11884808123878146,
#    'serving_throughput_bps': 19607896.171019677,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5600000000000003,
#   'context': {'time_s': 0.5600000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.4375138997812, 147.6258541572618),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74570445153084, -74.64251998975435, -73.58053470341878],
#    'sinr_db': [-8.682464301474958, -2.0106021077496488, -0.11650743549804311],
#    'throughput_bps': [3665081.937877742,
#     14087151.197047662,
#     19615566.291235536],
#    'serving_rsrp_dbm': -73.58053470341878,
#    'serving_sinr_db': -0.11650743549804311,
#    'serving_throughput_bps': 19615566.291235536,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5700000000000003,
#   'context': {'time_s': 0.5700000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.4942961038188, 147.70816929137843),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74542357871105, -74.64054302324189, -73.57661951571401],
#    'sinr_db': [-8.68524356245134, -2.01182693135808, -0.11416555705609156],
#    'throughput_bps': [3662879.945767238,
#     14084008.06068742,
#     19623242.547504146],
#    'serving_rsrp_dbm': -73.57661951571401,
#    'serving_sinr_db': -0.11416555705609156,
#    'serving_throughput_bps': 19623242.547504146,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5800000000000003,
#   'context': {'time_s': 0.5800000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.5510783078564, 147.79048442549504),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74514320920115, -74.6385665481296, -73.57270346728694],
#    'sinr_db': [-8.688023809151108, -2.0130533208854793, -0.11182244519121405],
#    'throughput_bps': [3660678.414147624,
#     14080861.45095556,
#     19630924.945518762],
#    'serving_rsrp_dbm': -73.57270346728694,
#    'serving_sinr_db': -0.11182244519121405,
#    'serving_throughput_bps': 19630924.945518762,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.5900000000000003,
#   'context': {'time_s': 0.5900000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.607860511894, 147.87279955961165),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7448633430572, -74.63659056493475, -73.56878655784647],
#    'sinr_db': [-8.690805042000076, -2.0142812773657868, -0.10947809918127092],
#    'throughput_bps': [3658477.343397128,
#     14077711.367254118,
#     19638613.49097813],
#    'serving_rsrp_dbm': -73.56878655784647,
#    'serving_sinr_db': -0.10947809918127092,
#    'serving_throughput_bps': 19638613.49097813,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.6000000000000003,
#   'context': {'time_s': 0.6000000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.6646427159317, 147.95511469372826),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74458398033522, -74.6346150741748, -73.56486878710153],
#    'sinr_db': [-8.6935872614245, -2.015510801833039, -0.10713251830382504],
#    'throughput_bps': [3656276.7338937493,
#     14074557.808989096,
#     19646308.189586036],
#    'serving_rsrp_dbm': -73.56486878710153,
#    'serving_sinr_db': -0.10713251830382504,
#    'serving_throughput_bps': 19646308.189586036,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.6100000000000003,
#   'context': {'time_s': 0.6100000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.7214249199693, 148.03742982784487),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7443051210911, -74.6326400763674, -73.560950154761],
#    'sinr_db': [-8.696370467851104, -2.016741895321331, -0.10478570183617347],
#    'throughput_bps': [3654076.58601525,
#     14071400.775570588,
#     19654009.047051236],
#    'serving_rsrp_dbm': -73.560950154761,
#    'serving_sinr_db': -0.10478570183617347,
#    'serving_throughput_bps': 19654009.047051236,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 0.6200000000000003,
#   'context': {'time_s': 0.6200000000000003,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (664.7782071240069, 148.1197449619615),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.74402676538061, -74.63066557203041, -73.55703066053367],
#    'sinr_db': [-8.69915466170699, -2.0179745588649487, -0.10243764905524866],
#    'throughput_bps': [3651876.900139207,
# ...
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70510923655394, -73.09785643574902, -69.55741223922742],
#    'sinr_db': [-11.741730238683024, -3.944760429914421, 2.675165122756905],
#    'throughput_bps': [1870169.899823148, 9774478.607262949, 30234109.87661417],
#    'serving_rsrp_dbm': -69.55741223922742,
#    'serving_sinr_db': 2.675165122756905,
#    'serving_throughput_bps': 30234109.87661417,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.809999999999835,
#   'context': {'time_s': 9.809999999999835,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (716.9610526345901, 223.76735321512828),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7053040188042, -73.096572330195, -69.55257866326285],
#    'sinr_db': [-11.745667633967628, -3.947863301260049, 2.6789813807671496],
#    'throughput_bps': [1868528.8459076926,
#     9768556.492492478,
#     30250575.291284986],
#    'serving_rsrp_dbm': -69.55257866326285,
#    'serving_sinr_db': 2.6789813807671496,
#    'serving_throughput_bps': 30250575.291284986,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.819999999999835,
#   'context': {'time_s': 9.819999999999835,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.0178348386278, 223.8496683492449),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70549931243937, -73.09528923987811, -69.54774397647915],
#    'sinr_db': [-11.749606618064911, -3.9509686259368877, 2.6827995986486135],
#    'throughput_bps': [1866888.5245632506,
#     9762632.714077985,
#     30267054.237782065],
#    'serving_rsrp_dbm': -69.54774397647915,
#    'serving_sinr_db': 2.6827995986486135,
#    'serving_throughput_bps': 30267054.237782065,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.829999999999835,
#   'context': {'time_s': 9.829999999999835,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.0746170426654, 223.9319834833615),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70569511741985, -73.09400716534923, -69.54290817871265],
#    'sinr_db': [-11.753547191792954, -3.954076404654508, 2.68661977710214],
#    'throughput_bps': [1865248.9360307893,
#     9756707.276904285,
#     30283546.725613385],
#    'serving_rsrp_dbm': -69.54290817871265,
#    'serving_sinr_db': 2.68661977710214,
#    'serving_throughput_bps': 30283546.725613385,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.839999999999835,
#   'context': {'time_s': 9.839999999999835,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.131399246703, 224.01429861747812),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70589143370601, -73.09272610715904, -69.53807126980033],
#    'sinr_db': [-11.757489355969714, -3.9571866381213456, 2.6904419168277998],
#    'throughput_bps': [1863610.0805512066,
#     9750780.18586206,
#     30300052.764285773],
#    'serving_rsrp_dbm': -69.53807126980033,
#    'serving_sinr_db': 2.6904419168277998,
#    'serving_throughput_bps': 30300052.764285773,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.849999999999834,
#   'context': {'time_s': 9.849999999999834,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.1881814507407, 224.09661375159473),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7060882612581, -73.09144606585801, -69.53323324957962],
#    'sinr_db': [-11.761433111413169, -3.960299327044838, 2.694266018525054],
#    'throughput_bps': [1861971.9583653244,
#     9744851.445847569,
#     30316572.363305602],
#    'serving_rsrp_dbm': -69.53323324957962,
#    'serving_sinr_db': 2.694266018525054,
#    'serving_throughput_bps': 30316572.363305602,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.859999999999834,
#   'context': {'time_s': 9.859999999999834,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.2449636547783, 224.17892888571134),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70628560003625, -73.0901670419964, -69.5283941178886],
#    'sinr_db': [-11.765378458941102, -3.96341447213135, 2.6980920828926314],
#    'throughput_bps': [1860334.569713925,
#     9738921.061762812,
#     30333105.532178234],
#    'serving_rsrp_dbm': -69.5283941178886,
#    'serving_sinr_db': 2.6980920828926314,
#    'serving_throughput_bps': 30333105.532178234,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.869999999999834,
#   'context': {'time_s': 9.869999999999834,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.3017458588159, 224.26124401982796),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70648345000052, -73.08888903612424, -69.52355387456583],
#    'sinr_db': [-11.769325399371303, -3.9665320740862002, 2.701920110628597],
#    'throughput_bps': [1858697.914837703, 9732989.03851542, 30349652.28040833],
#    'serving_rsrp_dbm': -69.52355387456583,
#    'serving_sinr_db': 2.701920110628597,
#    'serving_throughput_bps': 30349652.28040833,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.879999999999834,
#   'context': {'time_s': 9.879999999999834,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.3585280628536, 224.34355915394457),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70668181111087, -73.08761204879134, -69.51871251945047],
#    'sinr_db': [-11.773273933521459, -3.969652133613602, 2.7057501024302857],
#    'throughput_bps': [1857061.9939772764,
#     9727055.381018808,
#     30366212.617499527],
#    'serving_rsrp_dbm': -69.51871251945047,
#    'serving_sinr_db': 2.7057501024302857,
#    'serving_throughput_bps': 30366212.617499527,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.889999999999834,
#   'context': {'time_s': 9.889999999999834,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.4153102668912, 224.42587428806118),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70688068332711, -73.08633608054731, -69.51387005238223],
#    'sinr_db': [-11.777224062209143, -3.972774651416702, 2.70958205899432],
#    'throughput_bps': [1855426.8073732306,
#     9721120.094192043,
#     30382786.552954495],
#    'serving_rsrp_dbm': -69.51387005238223,
#    'serving_sinr_db': 2.70958205899432,
#    'serving_throughput_bps': 30382786.552954495,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': {'task_id': 47,
#    'offload_target': 'edge',
#    'latency_s': 0.653673943367965,
#    'deadline_s': 0.05000000000000071,
#    'deadline_met': False,
#    'energy_j': 0.19374375983061148}},
#  {'time_s': 9.899999999999833,
#   'context': {'time_s': 9.899999999999833,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.4720924709288, 224.5081894221778),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70708006660901, -73.08506113194153, -69.50902647320136],
#    'sinr_db': [-11.781175786251879, -3.975899628197641, 2.713415981016689],
#    'throughput_bps': [1853792.355266049,
#     9715183.182959747,
#     30399374.096275307],
#    'serving_rsrp_dbm': -69.50902647320136,
#    'serving_sinr_db': 2.713415981016689,
#    'serving_throughput_bps': 30399374.096275307,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.909999999999833,
#   'context': {'time_s': 9.909999999999833,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.5288746749665, 224.5905045562944),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70727996091621, -73.08378720352314, -69.50418178174868],
#    'sinr_db': [-11.7851291064671, -3.979027064657454, 2.7172518691926535],
#    'throughput_bps': [1852158.6378961592,
#     9709244.652252242,
#     30415975.25696294],
#    'serving_rsrp_dbm': -69.50418178174868,
#    'serving_sinr_db': 2.7172518691926535,
#    'serving_throughput_bps': 30415975.25696294,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.919999999999833,
#   'context': {'time_s': 9.919999999999833,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.5856568790041, 224.67281969041102),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70748036620823, -73.0825142958411, -69.49933597786558],
#    'sinr_db': [-11.78908402367208, -3.9821569614960755, 2.721089724216717],
#    'throughput_bps': [1850525.6555039342,
#     9703304.507005582,
#     30432590.04451723],
#    'serving_rsrp_dbm': -69.49933597786558,
#    'serving_sinr_db': 2.721089724216717,
#    'serving_throughput_bps': 30432590.04451723,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.929999999999833,
#   'context': {'time_s': 9.929999999999833,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.6424390830417, 224.75513482452763),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70768128244453, -73.08124240944412, -69.49448906139405],
#    'sinr_db': [-11.793040538684064, -3.9852893194123826, 2.7249295467827155],
#    'throughput_bps': [1848893.4083296729,
#     9697362.752161382,
#     30449218.46843717],
#    'serving_rsrp_dbm': -69.49448906139405,
#    'serving_sinr_db': 2.7249295467827155,
#    'serving_throughput_bps': 30449218.46843717,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.939999999999833,
#   'context': {'time_s': 9.939999999999833,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.6992212870794, 224.83744995864424),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70788270958445, -73.07997154488068, -69.48964103217658],
#    'sinr_db': [-11.796998652320209, -3.9884241391041595, 2.728771337583764],
#    'throughput_bps': [1847261.896613591,
#     9691419.392666947,
#     30465860.538220696],
#    'serving_rsrp_dbm': -69.48964103217658,
#    'serving_sinr_db': 2.728771337583764,
#    'serving_throughput_bps': 30465860.538220696,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.949999999999832,
#   'context': {'time_s': 9.949999999999832,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.756003491117, 224.91976509276085),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70808464758723, -73.07870170269908, -69.48479189005624],
#    'sinr_db': [-11.800958365397507, -3.9915614212682167, 2.732615097312337],
#    'throughput_bps': [1845631.1205958512,
#     9685474.43347498,
#     30482516.263365027],
#    'serving_rsrp_dbm': -69.48479189005624,
#    'serving_sinr_db': 2.732615097312337,
#    'serving_throughput_bps': 30482516.263365027,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.959999999999832,
#   'context': {'time_s': 9.959999999999832,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.8127856951546, 225.00208022687747),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70828709641198, -73.07743288344733, -69.47994163487674],
#    'sinr_db': [-11.804919678732876, -3.994701166600078, 2.7364608266600268],
#    'throughput_bps': [1844001.0805165588, 9679527.879544191, 30499185.6533656],
#    'serving_rsrp_dbm': -69.47994163487674,
#    'serving_sinr_db': 2.7364608266600268,
#    'serving_throughput_bps': 30499185.6533656,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.969999999999832,
#   'context': {'time_s': 9.969999999999832,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.8695678991922, 225.08439536099408),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70849005601778, -73.0761650876733, -69.4750902664823],
#    'sinr_db': [-11.808882593143126, -3.9978433757943552, 2.740308526317858],
#    'throughput_bps': [1842371.77661573, 9673579.735838555, 30515868.717717417],
#    'serving_rsrp_dbm': -69.4750902664823,
#    'serving_sinr_db': 2.740308526317858,
#    'serving_throughput_bps': 30515868.717717417,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.979999999999832,
#   'context': {'time_s': 9.979999999999832,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.9263501032299, 225.1667104951107),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70869352636353, -73.07489831592454, -69.47023778471768],
#    'sinr_db': [-11.812847109444979, -4.00098804954452, 2.74415819697609],
#    'throughput_bps': [1840743.2091333224,
#     9667630.007327763,
#     30532565.46591417],
#    'serving_rsrp_dbm': -69.47023778471768,
#    'serving_sinr_db': 2.74415819697609,
#    'serving_throughput_bps': 30532565.46591417,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.989999999999831,
#   'context': {'time_s': 9.989999999999831,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (717.9831323072675, 225.2490256292273),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.7088975074081, -73.07363256874847, -69.46538418942832],
#    'sinr_db': [-11.816813228455004, -4.004135188542939, 2.7480098393242427],
#    'throughput_bps': [1839115.378309229,
#     9661678.698987098,
#     30549275.907448336],
#    'serving_rsrp_dbm': -69.46538418942832,
#    'serving_sinr_db': 2.7480098393242427,
#    'serving_throughput_bps': 30549275.907448336,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  {'time_s': 9.999999999999831,
#   'context': {'time_s': 9.999999999999831,
#    'service_type': 'VR',
#    'latency_budget_s': 0.05,
#    'ue_position': (718.0399145113051, 225.33134076334392),
#    'ue_speed_mps': 10.0,
#    'serving_cell_id': 2,
#    'rsrp_dbm': [-79.70910199911019, -73.0723678466922, -69.46052948046015],
#    'sinr_db': [-11.820780950989674, -4.00728479348089, 2.7518634540511115],
#    'throughput_bps': [1837488.2843832602,
#     9655725.815797428,
#     30566000.051811267],
#    'serving_rsrp_dbm': -69.46052948046015,
#    'serving_sinr_db': 2.7518634540511115,
#    'serving_throughput_bps': 30566000.051811267,
#    'user_pref': {'latency_weight': 0.7, 'energy_weight': 0.3}},
#   'decision': {'handover_target': 2, 'offload_target': 'edge'},
#   'task_info': None},
#  ...]

# %%
# !jupyter nbconvert --to python simulation.ipynbon --output simulation.py
# Out:
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
#     Equivalent to: [--JupyterApp.answer_yes=True]
# --execute
#     Execute the notebook prior to export.
#     Equivalent to: [--ExecutePreprocessor.enabled=True]
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#     Equivalent to: [--ExecutePreprocessor.allow_errors=True]
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#     Equivalent to: [--NbConvertApp.from_stdin=True]
# --stdout
#     Write notebook output to stdout instead of files.
#     Equivalent to: [--NbConvertApp.writer_class=StdoutWriter]
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#             relevant when converting to notebook format)
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory=]
# --clear-output
#     Clear output of current file and save in place,
#             overwriting the existing notebook.
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --ClearOutputPreprocessor.enabled=True]
# --no-prompt
#     Exclude input and output prompts from converted document.
#     Equivalent to: [--TemplateExporter.exclude_input_prompt=True --TemplateExporter.exclude_output_prompt=True]
# --no-input
#     Exclude input cells and output prompts from converted document.
#             This mode is ideal for generating code-free reports.
#     Equivalent to: [--TemplateExporter.exclude_output_prompt=True --TemplateExporter.exclude_input=True --TemplateExporter.exclude_input_prompt=True]
# --allow-chromium-download
#     Whether to allow downloading chromium if no suitable version is found on the system.
#     Equivalent to: [--WebPDFExporter.allow_chromium_download=True]
# --disable-chromium-sandbox
#     Disable chromium security sandbox when converting to PDF..
#     Equivalent to: [--WebPDFExporter.disable_sandbox=True]
# --show-input
#     Shows code input. This flag is only useful for dejavu users.
#     Equivalent to: [--TemplateExporter.exclude_input=False]
# --embed-images
#     Embed the images as base64 dataurls in the output. This flag is only useful for the HTML/WebPDF/Slides exports.
#     Equivalent to: [--HTMLExporter.embed_images=True]
# --sanitize-html
#     Whether the HTML in Markdown cells and cell outputs should be sanitized..
#     Equivalent to: [--HTMLExporter.sanitize_html=True]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Application.log_level]
# --config=<Unicode>
#     Full path of a config file.
#     Default: ''
#     Equivalent to: [--JupyterApp.config_file]
# --to=<Unicode>
#     The export format to be used, either one of the built-in formats
#             ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'qtpdf', 'qtpng', 'rst', 'script', 'slides', 'webpdf']
#             or a dotted object name that represents the import path for an
#             ``Exporter`` class
#     Default: ''
#     Equivalent to: [--NbConvertApp.export_format]
# --template=<Unicode>
#     Name of the template to use
#     Default: ''
#     Equivalent to: [--TemplateExporter.template_name]
# --template-file=<Unicode>
#     Name of the template file to use
#     Default: None
#     Equivalent to: [--TemplateExporter.template_file]
# --theme=<Unicode>
#     Template specific theme(e.g. the name of a JupyterLab CSS theme distributed
#     as prebuilt extension for the lab template)
#     Default: 'light'
#     Equivalent to: [--HTMLExporter.theme]
# --sanitize_html=<Bool>
#     Whether the HTML in Markdown cells and cell outputs should be sanitized.This
#     should be set to True by nbviewer or similar tools.
#     Default: False
#     Equivalent to: [--HTMLExporter.sanitize_html]
# --writer=<DottedObjectName>
#     Writer class used to write the
#                                         results of the conversion
#     Default: 'FilesWriter'
#     Equivalent to: [--NbConvertApp.writer_class]
# --post=<DottedOrNone>
#     PostProcessor class used to write the
#                                         results of the conversion
#     Default: ''
#     Equivalent to: [--NbConvertApp.postprocessor_class]
# --output=<Unicode>
#     Overwrite base name use for output files.
#                 Supports pattern replacements '{notebook_name}'.
#     Default: '{notebook_name}'
#     Equivalent to: [--NbConvertApp.output_base]
# --output-dir=<Unicode>
#     Directory to write output(s) to. Defaults
#                                   to output to the directory of each notebook. To recover
#                                   previous default behaviour (outputting to the current
#                                   working directory) use . as the flag value.
#     Default: ''
#     Equivalent to: [--FilesWriter.build_directory]
# --reveal-prefix=<Unicode>
#     The URL prefix for reveal.js (version 3.x).
#             This defaults to the reveal CDN, but can be any url pointing to a copy
#             of reveal.js.
#             For speaker notes to work, this must be a relative path to a local
#             copy of reveal.js: e.g., "reveal.js".
#             If a relative path is given, it must be a subdirectory of the
#             current directory (from which the server is run).
#             See the usage documentation
#             (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow)
#             for more details.
#     Default: ''
#     Equivalent to: [--SlidesExporter.reveal_url_prefix]
# --nbformat=<Enum>
#     The nbformat version to write.
#             Use this to downgrade notebooks.
#     Choices: any of [1, 2, 3, 4]
#     Default: 4
#     Equivalent to: [--NotebookExporter.nbformat_version]
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#             > jupyter nbconvert mynotebook.ipynb --to html
#
#             Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'qtpdf', 'qtpng', 'rst', 'script', 'slides', 'webpdf'].
#
#             > jupyter nbconvert --to latex mynotebook.ipynb
#
#             Both HTML and LaTeX support multiple output templates. LaTeX includes
#             'base', 'article' and 'report'.  HTML includes 'basic', 'lab' and
#             'classic'. You can specify the flavor of the format used.
#
#             > jupyter nbconvert --to html --template lab mynotebook.ipynb
#
#             You can also pipe the output to stdout, rather than a file
#
#             > jupyter nbconvert mynotebook.ipynb --stdout
#
#             PDF is generated via latex
#
#             > jupyter nbconvert mynotebook.ipynb --to pdf
#
#             You can get (and serve) a Reveal.js-powered slideshow
#
#             > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#             Multiple notebooks can be given at the command line in a couple of
#             different ways:
#
#             > jupyter nbconvert notebook*.ipynb
#             > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#             or you can specify the notebooks list in a config file, containing::
#
#                 c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#             > jupyter nbconvert --config mycfg.py
#
# To see all available configurables, use `--help-all`.
# [NbConvertApp] WARNING | pattern 'simulation.ipynbon' matched no files
